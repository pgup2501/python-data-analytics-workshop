# %% [markdown]
# # MissingNo library for Cleanup
#
# [missingno library](https://pypi.org/project/missingno/)
#
# Install it as follows:
#
# ```bash
# # for conda
# $  conda install missingno
#
# # or for pip
# $  pip install missingno
# ```
#
# ## References
#
# - [Oil well log analysis](https://towardsdatascience.com/using-the-missingno-python-library-to-identify-and-visualise-missing-data-prior-to-machine-learning-34c8c5b5f009)
# * [Streaming platform analysis](https://towardsdatascience.com/4-must-know-libraries-in-pandas-ecosystem-7c01326c4724)

# %% [markdown]
# ## Read Data - Streaming Movies

# %%
import pandas as pd

#df = pd.read_csv('https://raw.githubusercontent.com/elephantscale/datasets/master/movies/movies-on-streaming-platforms.csv')


## Well log data : https://zenodo.org/record/4351156
df = pd.read_csv('https://raw.githubusercontent.com/andymcdgeo/missingno_tutorial/main/xeek_train_subset.csv')

# %%
df.sample(10)
# Out:
#                WELL     DEPTH_MD        X_LOC      Y_LOC        Z_LOC  \
# 91096    16/10/2003  2283.341599  460440.3750  6453743.0 -2243.020996
# 36599    15/09/2017   565.453998  438591.9063  6478951.5  -543.439819
# 29898    15/09/2015  2263.504000  436806.9375  6463009.5 -2238.219971
# 121870    16/2-11 A  2163.979200  475594.2500  6519105.0 -1873.363647
# 63571    16/10/2001  1180.719790  444151.6563  6435550.0 -1155.669556
# 6724     15/09/2013  1516.576000  437639.5938  6470978.0 -1491.509644
# 15083    15/09/2013  2787.752000  437611.7500  6470983.5 -2762.304688
# 109250  16/11-1 ST3  2464.809201          NaN        NaN          NaN
# 46998    15/09/2017  2146.101998  438597.2188  6478960.5 -2123.977295
# 126126   16/02/2016  1133.126396  476768.1563  6523588.5 -1106.761597
#
#                    GROUP       FORMATION       CALI      RSHA      RMED  ...  \
# 91096       SHETLAND GP.         Hod Fm.   8.879908  2.690496  2.714899  ...
# ...

# %% [markdown]
# ## Pandas Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133198 entries, 0 to 133197
# Data columns (total 22 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   WELL         133198 non-null  object
#  1   DEPTH_MD     133198 non-null  float64
#  2   X_LOC        125805 non-null  float64
#  3   Y_LOC        125805 non-null  float64
#  4   Z_LOC        125805 non-null  float64
#  5   GROUP        133198 non-null  object
#  6   FORMATION    111632 non-null  object
#  7   CALI         133006 non-null  float64
#  8   RSHA         62039 non-null   float64
#  9   RMED         125556 non-null  float64
#  10  RDEP         125805 non-null  float64
#  11  RHOB         108053 non-null  float64
#  12  GR           133198 non-null  float64
#  13  NPHI         91725 non-null   float64
#  14  PEF          100840 non-null  float64
#  15  DTC          132635 non-null  float64
#  16  SP           93680 non-null   float64
# ...

# %%
df.describe()
# Out:
#             DEPTH_MD          X_LOC         Y_LOC          Z_LOC  \
# count  133198.000000  125805.000000  1.258050e+05  125805.000000
# mean     1792.944663  451235.640862  6.471392e+06   -1719.214522
# std       739.441515   15299.395264  3.094449e+04     740.536678
# min       415.261599  436790.843800  6.429286e+06   -3246.156250
# 25%      1182.822400  437640.781300  6.453743e+06   -2334.161865
# 50%      1747.524496  444152.093800  6.463019e+06   -1626.893433
# 75%      2413.874901  460442.093800  6.478963e+06   -1119.113525
# max      3272.024000  476770.156300  6.539631e+06    -375.251495
#
#                 CALI          RSHA           RMED           RDEP  \
# count  133006.000000  62039.000000  125556.000000  125805.000000
# mean       13.199399     10.561825       1.708851       1.743774
# std         3.561386    116.359983       9.127200      13.233330
# min         5.946157      0.130193      -0.008419       0.123068
# ...

# %%
df.isnull().sum()
# Out:
# WELL                0
# DEPTH_MD            0
# X_LOC            7393
# Y_LOC            7393
# Z_LOC            7393
# GROUP               0
# FORMATION       21566
# CALI              192
# RSHA            71159
# RMED             7642
# RDEP             7393
# RHOB            25145
# GR                  0
# NPHI            41473
# PEF             32358
# DTC               563
# SP              39518
# ROP              2744
# DTS            121014
# DCAL            76998
# DRHO            27659
# LITHOFACIES         0
# dtype: int64

# %% [markdown]
# ## Missing No

# %%
import missingno as msno

# %matplotlib inline
# Out:
# /home/sujee/anaconda3/envs/jpmc-pyds/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(df)
# Out:
# <AxesSubplot:>
